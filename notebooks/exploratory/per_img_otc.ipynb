# %%
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd ../../
# Out:
# /mnt/sda/otani/Experiments/eval-detection

# %%
data = json.load(open("tmp/otc_20210926_222847.json"))
otcs = np.asarray([x[1] for x in data])

# %%
plt.hist(otcs, bins=15)
# Out:
# (array([ 3.,  2.,  1.,  0.,  3.,  1.,  3.,  8., 12., 10., 25., 17.,  8.,
#          4.,  3.]),
#  array([0.20823238, 0.24400269, 0.279773  , 0.3155433 , 0.35131361,
#         0.38708391, 0.42285422, 0.45862453, 0.49439483, 0.53016514,
#         0.56593544, 0.60170575, 0.63747606, 0.67324636, 0.70901667,
#         0.74478697]),
#  <BarContainer object of 15 artists>)

# %%
for i in np.argsort(otcs)[::10]:
    im = plt.imread(f"outputs/shows/Faster-RCNN/{data[i][0]}")
    plt.imshow(im)
    plt.title(f"OTC = {data[i][1]:.3}")
    plt.show()

# %%
[data[i] for i in np.argsort(otcs)[::10]]
# Out:
# [['000000537827.jpg', 0.2082323834300041],
#  ['000000203317.jpg', 0.42526470124721527],
#  ['000000033707.jpg', 0.49248111930986244],
#  ['000000376284.jpg', 0.5238529406487942],
#  ['000000177934.jpg', 0.5571935642662827],
#  ['000000235784.jpg', 0.5732411422899791],
#  ['000000019924.jpg', 0.5864667644103368],
#  ['000000576566.jpg', 0.6058210370441278],
#  ['000000433774.jpg', 0.624766299618142],
#  ['000000027932.jpg', 0.6617415145867399]]
